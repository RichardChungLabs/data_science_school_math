# %% [markdown]
# from google.colab import drive
# drive.mount('/content/drive')
#
# cd /content/drive/MyDrive/03. data science /01. With Python/Basic.git/Python Basic
#
# !git config --global user.email 'h4zhistory@gmail.com'
# !git config --global user.name 'RichardChungLabs
#
#
# !git add Colab_with_python_Basic.ipynb
#
# !git commit -m 'Colab_with_python_Basic.ipynb'
#
# !git push

# %%
from google.colab import drive  
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/03. data science /0.artificial intelligence_math/data_science_school_math
# Out:
# /content/drive/MyDrive/03. data science /0.artificial intelligence_math/data_science_school_math

# %%
# !git config --global user.email 'h4zhistory@gmail.com'
# !git config --global user.name 'RichardChungLabs
# Out:
# /bin/bash: -c: line 0: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
# !git clone https://RichardChungLabs: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@github.com/RichardChungLabs/data_science_school_math
# Out:
# Cloning into 'data_science_school_math'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
cd /content/drive/MyDrive/03. data science /0.artificial intelligence_math/data_science_school_math
# Out:
# /content/drive/MyDrive/03. data science /0.artificial intelligence_math/data_science_school_math

# %%
# !git add  Colab_with_python_Basic_math.ipynb
# Out:
# fatal: pathspec 'Colab_with_python_Basic_math.ipynb' did not match any files

# %%
# !git commit -m 'Colab_with_python_Basic_math.ipynb'
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git push
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
